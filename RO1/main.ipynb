# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import BernoulliNB, GaussianNB, MultinomialNB
from sklearn.svm import SVC
import pandas as pd
import numpy as np


df = pd.read_csv('data/mammographic_masses_data.csv', delimiter=',', names=['in_1', 'in_2', 'in_3', 'in_4', 'in_5', 'out_1'])


display(df)
# Out:
#     in_1 in_2 in_3 in_4 in_5  out_1
# 0      5   67    3    5    3      1
# 1      4   43    1    1    ?      1
# 2      5   58    4    5    3      1
# 3      4   28    1    1    3      0
# 4      5   74    1    5    ?      1
# ..   ...  ...  ...  ...  ...    ...
# 956    4   47    2    1    3      0
# 957    4   56    4    5    3      1
# 958    4   64    4    5    3      0
# 959    5   66    4    5    3      1
# 960    4   62    3    3    3      0
#
# [961 rows x 6 columns]

# %%
df = df.replace('?', np.NaN)
if not df.isnull().values.any():
    display("This DataFrame doesn't exist null values")
else: 
    df = df.dropna(how='any',axis=0)
    display('Rows with null values was deleted from the DataFrame')

X = df.copy().drop(columns='out_1').to_numpy()
y = df['out_1'].copy().to_numpy()
test_sizes_list = [0.4, 0.3, 0.2, 0.1]

result_df = pd.DataFrame(columns = ['Classifier', 'Test size', 'Accuracy'])

for clf in BernoulliNB(), GaussianNB(), GradientBoostingClassifier(), SVC(), MultinomialNB():
    
    for ratio in test_sizes_list:

        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=ratio)
        clf.fit(X=X_train, y=y_train)
        prediction = clf.predict(X_test)

        new_row = {'Classifier':str(clf.__class__.__name__), 'Test size':ratio,'Accuracy':clf.score(X_test, y_test)}

        result_df = result_df.append(new_row, ignore_index = True)

        
display(result_df)
result_df.to_excel("RO_LAB1_RESULTS.xlsx", index=False, sheet_name='Data', engine='xlsxwriter')
# Out:
# 'Rows with null values was deleted from the DataFrame'
#                     Classifier  Test size  Accuracy
# 0                  BernoulliNB        0.4  0.518072
# 1                  BernoulliNB        0.3  0.481928
# 2                  BernoulliNB        0.2  0.512048
# 3                  BernoulliNB        0.1  0.518072
# 4                   GaussianNB        0.4  0.801205
# 5                   GaussianNB        0.3  0.823293
# 6                   GaussianNB        0.2  0.855422
# 7                   GaussianNB        0.1  0.771084
# 8   GradientBoostingClassifier        0.4  0.834337
# 9   GradientBoostingClassifier        0.3  0.819277
# 10  GradientBoostingClassifier        0.2  0.861446
# 11  GradientBoostingClassifier        0.1  0.843373
# 12                         SVC        0.4  0.746988
# 13                         SVC        0.3  0.803213
# 14                         SVC        0.2  0.771084
# 15                         SVC        0.1  0.795181
# ...
